# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Fare'] = df['Fare'].fillna(df['Fare'].median())

df['HasCabin'] = df['Cabin'].notna().astype(int)
df.drop(columns=['Cabin'], inplace=True)

df['Sex'] = df['Sex'].map({'male':0,'female':1})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    str
#  11  HasCabin     891 non-null    int64
# dtypes: float64(2), int64(7), str(3)
# memory usage: 83.7 KB
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.352413   29.361582
# ...

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Pclass'].describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %%
df['Sex'].describe()
# Out:
# count    891.000000
# mean       0.352413
# std        0.477990
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Sex, dtype: float64

# %%
df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# 0    0.188908
# 1    0.742038
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.groupby('Embarked')['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64

# %%
df[df['Survived'] == 1]['Age'].mean()
# Out:
# np.float64(28.29143274853801)

# %%
df[df['Survived'] == 0]['Age'].mean()
# Out:
# np.float64(30.028233151183972)

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.034212 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351 -0.064910 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.339898  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.081163  0.114631
# Age             0.034212 -0.064910 -0.339898 -0.081163  1.000000 -0.233296
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.233296  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.172482  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.096688  0.159651
# HasCabin        0.019919  0.316912 -0.725541  0.140391  0.240314 -0.040460
#
#                 Parch      Fare  HasCabin
# PassengerId -0.001652  0.012658  0.019919
# Survived     0.081629  0.257307  0.316912
# Pclass       0.018443 -0.549500 -0.725541
# Sex          0.245489  0.182333  0.140391
# ...

# %%
df['FareGroup'] = pd.qcut(df['Fare'], 4, labels=['cheep','normal price','expensive','very expensive'])
df.groupby('FareGroup')['Survived'].mean()
# Out:
# FareGroup
# cheep             0.197309
# normal price      0.303571
# expensive         0.454955
# very expensive    0.581081
# Name: Survived, dtype: float64

# %%
df.groupby('HasCabin')['Survived'].mean()
# Out:
# HasCabin
# 0    0.299854
# 1    0.666667
# Name: Survived, dtype: float64

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df.groupby('FamilySize')['Survived'].mean()
# Out:
# FamilySize
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %%
df.pivot_table(index='Sex', columns='Pclass', values='Survived', aggfunc='mean')
# Out:
# Pclass         1         2         3
# Sex
# 0       0.368852  0.157407  0.135447
# 1       0.968085  0.921053  0.500000

# %%
df.corr(numeric_only=True)['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Sex            0.543351
# HasCabin       0.316912
# Fare           0.257307
# Parch          0.081629
# FamilySize     0.016639
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.064910
# Pclass        -0.338481
# Name: Survived, dtype: float64
